# %%
import numpy as np

# %%
import pickle

with open("/global/cfs/cdirs/des/zhou/cluster_shear/data/sims/sim_data_1_0.pkl", "rb") as f:
    data = pickle.load(f)
    sim_data = data['sim_data']
    psf = data['psf']

# %%
sim_data
# Out:
# {'band_data': {'i': [<lsst.afw.image._exposure.ExposureF at 0x7fd41bcdd4b0>]},
#  'coadd_wcs': FITS standard SkyWcs:
#  Sky Origin: (200.0000000000, +0.0000000000)
#  Pixel Origin: (1748.5, 1748.5)
#  Pixel Scale: 0.2 arcsec/pixel,
#  'psf_dims': (51, 51),
#  'coadd_dims': (500, 500),
#  'coadd_bbox': Box2I(corner=Point2I(1000, 450), dimensions=Extent2I(500, 500)),
#  'bright_info': array([], dtype=int64),
#  'truth_info': array([(200.02726779, -0.05816998, 2.0319581 ,  2.63679736e+02,  2.57439937e+02),
#         (200.02607084, -0.06920377, 1.80608428,  2.85224898e+02,  5.88317038e+01),
#         (200.02324456, -0.05376385, 0.7365064 ,  3.36097925e+02,  3.36750163e+02),
#         (200.03232307, -0.06251808, 1.11696577,  1.72684680e+02,  1.79174145e+02),
#         (200.02221929, -0.05791889, 0.29010129,  3.54552713e+02,  2.61959503e+02),
#         (200.03559041, -0.06022578, 0.57834911,  1.13872617e+02,  2.20435494e+02),
# ...

# %%
psf = sim_data['band_data']['i'][0].getPsf()
wcs = sim_data['band_data']['i'][0].getWcs()

# %%
print(psf)
print(wcs)
# Out:
# None
# FITS standard SkyWcs:
# Sky Origin: (200.0277222201, -0.0582777509)
# Pixel Origin: (254.5, 254.5)
# Pixel Scale: 0.2 arcsec/pixel
